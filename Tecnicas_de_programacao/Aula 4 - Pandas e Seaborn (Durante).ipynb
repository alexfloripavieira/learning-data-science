# %% [markdown]
# # Aula 4 - Pandas e Seaborn
#
# Nessa aula, iremos tratar dos seguintes conteúdos:
# - Combinando DataFrames
# - Agrupamentos no Pandas
# - Seaborn
# - Arquivos de Dados do Seaborn
# - Outras Visualizações do Seaborn

# %%
import pandas as pd
import numpy as np

# %%
world_happiness = pd.read_csv('../datasets/world-happiness-report.csv')

# %%
world_happiness[world_happiness['year'] == 2020]['Life Ladder'].mean()
# Out:
# 5.8405999999999985

# %%
world_happiness_2021 = pd.read_csv('../datasets/world-happiness-report-2021.csv')

# %%
world_happiness_2021['Ladder score'].mean()
# Out:
# 5.532838926174497

# %% [markdown]
# ## Comentario interessante
# __Marcelo Heinrich__ -  Alguns sets do Kaggle tem dados com encoding  não ascii ai temos que usar o parâmetro "encoding " no read_csv, ex.: df = pd.read_csv(''meuset.csv', encoding = 'ISO-8859-1')

# %% [markdown]
# ## Combinando DataFrames
# __Pandas__ fornece um conjunto de métodos para combinar DataFrames, o que é extremamente útil em cenários envolvendo múltiplas fontes de dados. Em particular, os métodos:
# - __merge__ combina DataFrames com base nos rótulos das linhas ou valores das colunas
# - __concatenate__ combina DataFrames a partir de um eixo específico

# %% [markdown]
# ### merge
# O método __merge__ "funde" dois DataFrames, duas séries, ou uma série com um DataFrame.
#
# A fusão pode ser feita com base nos:
# - valores de duas colunas específicas, uma em cada DataFrame
# - valores de uma coluna em um dos DataFrame e rótulos das linhas no outro
# - valores dos rótulos das linhas em ambos os DataFrames (ou Séries)

# %%
# Construindo dois DataFrames que serão fundidos com o método 'merge'
df1 = pd.DataFrame({'key': ['b','b','a','c','a','a','b'], 
                   'data1': range(7)})

df2 = pd.DataFrame({'key': ['a','b','d','b','d'], 
                   'data2': range(5)})

# Print do primeiro Dataframe
print(df1)

# Print do Segundo Dataframe
print(df2)
# Out:
#   key  data1
# 0   b      0
# 1   b      1
# 2   a      2
# 3   c      3
# 4   a      4
# 5   a      5
# 6   b      6
#   key  data2
# 0   a      0
# 1   b      1
# 2   d      2
# 3   b      3
# 4   d      4

# %%
# Usando o merge a partir de uma chave primaria
pd.merge(df1, df2, on='key') ## Recebe dois dataframes e uma chave
# Out:
#   key  data1  data2
# 0   b      0      1
# 1   b      0      3
# 2   b      1      1
# 3   b      1      3
# 4   b      6      1
# 5   b      6      3
# 6   a      2      0
# 7   a      4      0
# 8   a      5      0

# %%
# Com o how podemos passar o tipo merge que queremos fazer (left, right, inner, outer)
pd.merge(df1, df2, on='key', how='right') ## .dtypes -> Mostra os tipos de dados
## NaN é como o python lida com nulos e brancos -> Quer dizer Not a Number
# Out:
#    key  data1  data2
# 0    a    2.0      0
# 1    a    4.0      0
# 2    a    5.0      0
# 3    b    0.0      1
# 4    b    1.0      1
# 5    b    6.0      1
# 6    d    NaN      2
# 7    b    0.0      3
# 8    b    1.0      3
# 9    b    6.0      3
# 10   d    NaN      4

# %%
df_merge = pd.merge(df1, df2, on='key', how='right')#.astype({'data1' : 'int32'})
df_merge[df_merge['data1'].isna()] = 0
df_merge.astype({'data1' : 'int32'})
# Out:
#    key  data1  data2
# 0    a      2      0
# 1    a      4      0
# 2    a      5      0
# 3    b      0      1
# 4    b      1      1
# 5    b      6      1
# 6    0      0      0
# 7    b      0      3
# 8    b      1      3
# 9    b      6      3
# 10   0      0      0

# %% [markdown]
# ### concat
# O método __concat__ é utilizado para juntar DataFrames ou Séries com base em um dos eixos.
# - __axis = 0__ concatena por linhas
# - __axis = 1__ concatena por colunas. Quando empregado em um conjunto de séries resulta em um DataFrame
#
# O método assume como parâmetro uma lista de DataFrames ou Séries.

# %%
# Construindo 3 séries especificando os rótulos das linhas
s1 = pd.Series([0, 1], index=['a', 'b'])
s2 = pd.Series([2, 3, 4], index=['c', 'd', 'e'])
s3 = pd.Series([1,5, 6], index=['a','f', 'd']) 

# Print das Series
print(s1)
print(s2)
print(s3)

# Contatenando as 3 séries na vertical (axis=0 por default)
# concat recebe uma lista de series ou dataframes
pd.concat([s1, s2, s3]) ## recebe uma lista de series ou dataframes
# Out:
# a    0
# b    1
# dtype: int64
# c    2
# d    3
# e    4
# dtype: int64
# a    1
# f    5
# d    6
# dtype: int64
# a    0
# b    1
# c    2
# d    3
# e    4
# a    1
# f    5
# d    6
# dtype: int64

# %%
# Concatenando as 3 séries por colunas especificando o parâmetro 'axis=1'
pd.concat([s1, s2, s3], axis=1)
# Out:
#      0    1    2
# a  0.0  NaN  1.0
# b  1.0  NaN  NaN
# c  NaN  2.0  NaN
# d  NaN  3.0  6.0
# e  NaN  4.0  NaN
# f  NaN  NaN  5.0

# %% [markdown]
# ### pivot
# O método __pivot__ é o equivalente do Pivot table do excel

# %%
df_titanic = pd.read_csv('../Python/titanic.csv')

### Parametros -> Dataset, valores = valores que vou calcular, index = linhas, columns = colunas
### aggfunc = Função agregada (que consolida os dados)
pd.pivot_table(df_titanic, values='Age', index='Pclass', columns='Sex', aggfunc=np.mean)
# Out:
# Sex        female       male
# Pclass
# 1       34.611765  41.281386
# 2       28.722973  30.740707
# 3       21.750000  26.507589

# %% [markdown]
# ## GroupBy e Agregadores

# %% [markdown]
# Podemos utilizar o __GroupBy__, para fsazer alguns cálculos de agrupamentos específicos (bem parecido com o que fazemos no SQL):

# %% [markdown]
# Funções agregadas são funções que consolidam informação:
#
# No SQL são 5:
# - Sum,
# - mean (ou avg),
# - count,
# - min,
# - max

# %%
# Calcula a média de Idade por Sexo
## para agruparmos usamos o metodo group by
## no parentesis passamos uma coluna ou um conjunto de colunas
## Depois precisamos passar entre colchetes o campo que vamos agrupar
## Por fim passamos a metrica que queremos

df_titanic.groupby(["Sex"])['Age'].mean()
# Out:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %% [markdown]
# Pode-se também calcular mais de uma métrica por vez utilizando o __GroupBy__ combinado com o método __agg:__

# %%
# Calculo das Métricas para o Agrupamento Sexo e Idade
# Quero calcular muitas metricas na mesma linha
# podemos usar o .agg e passar uma lista de metricas

df_titanic.groupby(['Sex'])['Age'].agg(["mean", "median", "std", "count"])
# Out:
#              mean  median        std  count
# Sex
# female  27.915709    27.0  14.110146    261
# male    30.726645    29.0  14.678201    453

# %%
# Com mais de uma categoria dentro do Groupby
# Quero ter mais de uma categoria
# Podemos passar no parentesis uma lista de colunas também

df_titanic.groupby(["Pclass", "Sex"])["Age"].agg(["mean", "median", "std", "count"])
# Out:
#                     mean  median        std  count
# Pclass Sex
# 1      female  34.611765    35.0  13.612052     85
#        male    41.281386    40.0  15.139570    101
# 2      female  28.722973    28.0  12.872702     74
#        male    30.740707    30.0  14.793894     99
# 3      female  21.750000    21.5  12.729964    102
#        male    26.507589    25.0  12.159514    253

# %%
# Mais de uma categoria e mais de uma métrica calculando
# Podemos calcular para um conjunto de dados diferentes as metricas
# basta passar no indexador (no colchete) uma lista de colunas

df_titanic.groupby(["Sex", "Pclass"])[["Age", 'Survived']].agg(["mean", "median", "std", "count"])
# Out:
#                      Age                          Survived                   \
#                     mean median        std count      mean median       std
# Sex    Pclass
# female 1       34.611765   35.0  13.612052    85  0.968085    1.0  0.176716
#        2       28.722973   28.0  12.872702    74  0.921053    1.0  0.271448
#        3       21.750000   21.5  12.729964   102  0.500000    0.5  0.501745
# male   1       41.281386   40.0  15.139570   101  0.368852    0.0  0.484484
#        2       30.740707   30.0  14.793894    99  0.157407    0.0  0.365882
#        3       26.507589   25.0  12.159514   253  0.135447    0.0  0.342694
#
#
#               count
# Sex    Pclass
# female 1         94
#        2         76
#        3        144
# male   1        122
#        2        108
#        3        347

# %% [markdown]
# ## Exercício

# %% [markdown]
# 1 - Utilize uma função agregada para saber a passagem média e também a soma do dinheiro gasto em passagens por ponto de embarque
#
# 2 - Utilize o pivot table para calcular o total de dinheiro gasto em passagens por homens e mulheres de classe

# %%
df_titanic.groupby(['Embarked'])['Fare'].agg(["mean", "sum"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/alexsander-vieira/Documentos/Python/Aula 4 - Pandas e Seaborn (Durante).ipynb Cell 29' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/alexsander-vieira/Documentos/Python/Aula%204%20-%20Pandas%20e%20Seaborn%20%28Durante%29.ipynb#ch0000028?line=0'>1</a> df_titanic.groupby(['Embarked'])['Fare'].agg(["mean", "sum"])
#
# NameError: name 'df_titanic' is not defined

# %%
pd.pivot_table(df_titanic, values='Fare', index='Pclass', columns='Sex', aggfunc=np.sum)
# Out:
# Sex        female       male
# Pclass
# 1       9975.8250  8201.5875
# 2       1669.7292  2132.1125
# 3       2321.1086  4393.5865

# %% [markdown]
# <img src="data:image/jpeg;base64,..." width=600>

# %% [markdown]
# ##

# %% [markdown]
# ## Seaborn

# %% [markdown]
# Quando falamos de visualização de dados, além do __Matplotlib__ uma das principais bibliotecas que temos para utilizar é o __Seaborn__.<br>
# <br>
# O __Seaborn__ é uma biblioteca baseado no próprio _Matplotlib_, mas focada em gráficos de alta performance, ou seja iremos fazer gráficos de uma maneira __mais simples__ e com uma __riqueza maior nas informações__ que queremos passar com os gráficos.

# %% [markdown]
# Para instalar o __Seaborn__ no seu Jupyter Notebooks (quando não tenha já instalado), precisa ser descomentar e rodar o código abaixo:

# %%
#!pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in c:\users\inspira\appdata\roaming\python\python39\site-packages (0.11.2)
# Requirement already satisfied: pandas>=0.23 in c:\program files\python39\lib\site-packages (from seaborn) (1.3.3)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\inspira\appdata\roaming\python\python39\site-packages (from seaborn) (3.5.0)
# Requirement already satisfied: scipy>=1.0 in c:\users\inspira\appdata\roaming\python\python39\site-packages (from seaborn) (1.7.3)
# Requirement already satisfied: numpy>=1.15 in c:\program files\python39\lib\site-packages (from seaborn) (1.21.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\program files\python39\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: setuptools-scm>=4 in c:\users\inspira\appdata\roaming\python\python39\site-packages (from matplotlib>=2.2->seaborn) (6.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\program files\python39\lib\site-packages (from matplotlib>=2.2->seaborn) (21.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\inspira\appdata\roaming\python\python39\site-packages (from matplotlib>=2.2->seaborn) (8.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\inspira\appdata\roaming\python\python39\site-packages (from matplotlib>=2.2->seaborn) (4.28.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\inspira\appdata\roaming\python\python39\site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\inspira\appdata\roaming\python\python39\site-packages (from matplotlib>=2.2->seaborn) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\program files\python39\lib\site-packages (from matplotlib>=2.2->seaborn) (2.4.7)
# Requirement already satisfied: pytz>=2017.3 in c:\program files\python39\lib\site-packages (from pandas>=0.23->seaborn) (2021.1)
# Requirement already satisfied: six>=1.5 in c:\program files\python39\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# Requirement already satisfied: tomli>=1.0.0 in c:\users\inspira\appdata\roaming\python\python39\site-packages (from setuptools-scm>=4->matplotlib>=2.2->seaborn) (1.2.2)
# Requirement already satisfied: setuptools in c:\program files\python39\lib\site-packages (from setuptools-scm>=4->matplotlib>=2.2->seaborn) (56.0.0)
# WARNING: You are using pip version 21.1.3; however, version 22.0.3 is available.
# You should consider upgrading via the 'c:\program files\python39\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# Primeiro passo será importarmos a bibloteca para o notebook:

# %%
# Carregando a Biblioteca
import seaborn as sns

# %% [markdown]
# Além do __Seaborn__, vamos importar algumas outras bibliotecas que serão úteis durante a aula:

# %%
# Carregando outras bibliotecas bem úteis
import matplotlib.pyplot as plt

# %% [markdown]
# ##

# %% [markdown]
# ## Arquivos de Datasets do Seaborn

# %% [markdown]
# Utilizando a função __load_dataset__, conseguimos carregar alguns datasets bem conhecidos na aprendizagem de Data Science como por exemplo o _Titanic_, _Tips_ entre outros. Podemos consultar todos os datasets disponíveis usando a função __get_dataset_names__:

# %%
# usando a função get_dataset_names para saber todos os datasets disponíveis
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %% [markdown]
# Vamos utilizar o dataset _Iris_ para começar as análises:

# %%
# Carrega o dataset Iris
iris = sns.load_dataset('iris')

# %%
iris['species'].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %% [markdown]
# O _Iris_ é um dataset bem conhecido sobre a classificação de 3 espécies de plantas: _setosa_, _virgínica_ e _versicolor_:<br><br>
# <img src="https://miro.medium.com/max/1000/1*Hh53mOF4Xy4eORjLilKOwA.png" width = 800>

# %% [markdown]
# Antes de partirmos para análises e novos gráficos de fato, vamos começar a exercitar as boas práticas quando trabalhamos com análise de dados:

# %%
# Olhando sobre o DataFrame e seu preenchimento
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
# Print das primeiras linhas do Iris
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# Levantando as principais métricas estatísticas para o DataFrame
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# Vamos dar uma olhada como está dividido em cada uma das espécies da _Iris_:

# %%
# Value counts das categorias
iris['species'].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %% [markdown]
# ##

# %% [markdown]
# ## Seaborn x Matplotlib

# %% [markdown]
# Primeiramente, vamos recordar como fazer um gráfico de dispersão usando o __Matplotlib__:

# %%
## Os comandos do matplotlib só são executados quando usamos o 
## plt.show()
# Ajustando o tamanho da Figura
plt.figure(figsize = (16, 8)) ## Tamanho da figura em polegadas

# Gráfico de dispersão
plt.scatter('sepal_length', 'sepal_width', data = iris)

# Coloca o titulo
plt.title('Comprimento pela Largura da Sépala', fontsize = 25)

# Titulo para eixo X
plt.xlabel('Comprimento', fontsize=15)

# Titulo para eixo Y
plt.ylabel('Largura', fontsize=15)

# Tamanho da fonte da grade X
plt.xticks(fontsize = 12)

# Tamanho da fonte da grade Y
plt.yticks(fontsize = 12)

# Colocando Grid no Gráfico
plt.grid()

# Mostra o nosso Gráfico
plt.show()

# %% [markdown]
# No __Seaborn__, podemos fazer o mesmo gráfico utilizando a função __scatterplot__:

# %%
# Ajustando o tamanho da Figura

plt.figure(figsize = (16, 8)) ## Tamanho da figura em polegadas

# Gráfico de dispersão
sns.scatterplot(data = iris, x='sepal_length', y='sepal_width')

# Coloca o titulo
plt.title('Comprimento pela Largura da Sépala', fontsize = 25)

# Titulo para eixo X
plt.xlabel('Comprimento', fontsize=15)

# Titulo para eixo Y
plt.ylabel('Largura', fontsize=15)

# Tamanho da fonte da grade X
plt.xticks(fontsize = 12)

# Tamanho da fonte da grade Y
plt.yticks(fontsize = 12)

# Colocando Grid no Gráfico
plt.grid()

# Mostra o nosso Gráfico
plt.show()

# %% [markdown]
# Mas então, a primeira pergunta é: __quais são as vantagens de usar o Seaborn ao invés do Matplotlib?__<br><br>
# Vamos imaginar que queremos fazer o mesmo gráfico mas separando as pelos tipos de _Iris_ (ou seja, separar pelas classes):

# %%
# Separe o DataFrame entre as 3 classes
df_set = iris[iris['species'] == 'setosa'] 
df_ver = iris[iris['species'] == 'versicolor'] 
df_vir = iris[iris['species'] == 'virginica'] 

# Ajustando o tamanho da Figura
plt.figure(figsize = (16,8))

# Gráfico de Dispersão
plt.scatter('sepal_length', 'sepal_width', data = df_set)
plt.scatter('sepal_length', 'sepal_width', data = df_ver)
plt.scatter('sepal_length', 'sepal_width', data = df_vir)


# Coloca o titulo
plt.title('Comprimento pela Largura da Sépala', fontsize = 25)

# Titulo para eixo X
plt.xlabel('Comprimento', fontsize=15)

# Titulo para eixo Y
plt.ylabel('Largura', fontsize=15)

# Tamanho da fonte da grade X
plt.xticks(fontsize = 12)

# Tamanho da fonte da grade Y
plt.yticks(fontsize = 12)

# Colocando Grid no Gráfico
plt.grid()

## Colocar legenda
plt.legend(['setosa', 'versicolor', 'virginica'])

# Mostra o nosso Gráfico
plt.show()

# %% [markdown]
# No __Seaborn__, sempre que quisermos quebrar um gráfico nas classes basta passar um parâmetro chamado __hue__:

# %%
# Ajustando o tamanho da Figura

plt.figure(figsize = (16, 8)) ## Tamanho da figura em polegadas

# Gráfico de dispersão
sns.scatterplot(data = iris, x='sepal_length', y='sepal_width', hue='species')

# Coloca o titulo
plt.title('Comprimento pela Largura da Sépala', fontsize = 25)

# Titulo para eixo X
plt.xlabel('Comprimento', fontsize=15)

# Titulo para eixo Y
plt.ylabel('Largura', fontsize=15)

# Tamanho da fonte da grade X
plt.xticks(fontsize = 12)

# Tamanho da fonte da grade Y
plt.yticks(fontsize = 12)

# Colocando Grid no Gráfico
plt.grid()

# Mostra o nosso Gráfico
plt.show()

# %% [markdown]
# E o __Seaborn__ nos permite customizar diversas detalhes do nosso gráfico:

# %%
# Ajustando o tamanho da Figura

plt.figure(figsize = (16, 8)) ## Tamanho da figura em polegadas

# Gráfico de dispersão
sns.scatterplot(data = iris, x='sepal_length', y='sepal_width',
               hue='species', hue_order= ['versicolor', 'setosa', 'virginica'])

# Coloca o titulo
plt.title('Comprimento pela Largura da Sépala', fontsize = 25)

# Titulo para eixo X
plt.xlabel('Comprimento', fontsize=15)

# Titulo para eixo Y
plt.ylabel('Largura', fontsize=15)

# Tamanho da fonte da grade X
plt.xticks(fontsize = 12)

# Tamanho da fonte da grade Y
plt.yticks(fontsize = 12)

# Colocando Grid no Gráfico
plt.grid()

# Mostra o nosso Gráfico
plt.show()

# %%
# Cria um valor de size no DataFrame
iris['size'] = iris['sepal_length'] * iris['sepal_width'] * 100

# Ajustando o tamanho da Figura
plt.figure(figsize=(16,12))

# Escolhendo um Pallete de Cores
palette = ["#FF6978", "#B1EDE8", "#6D435A"]

# Gráfico de Dispersão
sns.scatterplot(data = iris,
               x='sepal_length',
               y='sepal_width',
               palette=palette,
               hue = 'species',
               s = iris['size'])

# Coloca o titulo
plt.title('Comprimento pela Largura da Sépala', fontsize = 15)

# Titulo para eixo X
plt.xlabel('Comprimento', fontsize = 15)

# Titulo para eixo Y
plt.ylabel('Largura', fontsize = 15)

# Tamanho da fonte da grade X
plt.xticks(fontsize = 12)

# Tamanho da fonte da grade Y
plt.yticks(fontsize = 12)

# Colocando Grid no Gráfico
plt.grid()

# Mostra o nosso Gráfico
plt.show()

# %% [markdown]
# Um site bem interessante que vocês podem escolher cores para monta o Palette Cutsomizado é o [Coolors](https://coolors.co/)

# %%
titanic = sns.load_dataset('titanic')

# %% [markdown]
# ## Exercícios

# %% [markdown]
# 1 - Utilize o dataset do titanic, junto com a estratégia do scatter plot colorido (exemplos acima), para verificar se a idade em conjunto com a classe de passageiro é um bom classificador para sexo biologico
#
# 2 - Utilize a mesma estratégia para verificar se a idade em conjunto com a classe de passageiro é um bom classificador para sobrevivencia

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
plt.figure(figsize = (16,8))
sns.scatterplot(data = titanic, x = '', y='class', hue='sex', hue_order= ['male', 'female'])

# %%
plt.figure(figsize = (16,8))

# %%
sns.scatterplot(data = titanic, x = 'sex', y='class', hue='age', hue_order= ['male', 'female'])

# %%
plt.show()

# %% [markdown]
# ## Outras Visualizações do Seaborn

# %% [markdown]
# Vamos passar agora, por algumas das principais visualizações que acabam sendo utilizadas do __Seaborn__:

# %% [markdown]
# ### PairPlot

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
# Cria o pairplot
sns.pairplot(df_titanic[['Age', 'Sex', 'Pclass', 'Survived', 'Fare', 'Parch']], hue='Sex')
# Mostra o gráfico
plt.show()

# %% [markdown]
# ##

# %% [markdown]
# ### JointPlot

# %%
# Cria o Jointplot
sns.jointplot
# Mostra o Gráfico
plt.show()

# %% [markdown]
# ##

# %% [markdown]
# ### Distplot e Histplot

# %%
# Cria o distplot

#mostra o Gráfico
plt.show()

# %%
# Cria o displot


#mostra o Gráfico
plt.show()

# %%
# Cria o distplot

#mostra o Gráfico
plt.show()

# %% [markdown]
# ##

# %% [markdown]
# ### FacetGrid

# %%
# Cria o FacetGrid

# Cria o gráfico relacionado

# Mostra o Gráfico
plt.show()

# %% [markdown]
# ##

# %% [markdown]
# ### LMPlot

# %%
# Constroi o LMPlot


# Mostra o Gráfico
plt.show()

# %%
# Constroi o LMPlot


# Mostra o Gráfico
plt.show()

# %% [markdown]
# ##

# %% [markdown]
# ## Exercícios
#
# 1 - Verifique se alguma outra combinação de variáveis é um bom classificador para sexo biologico
#
# 2 - Gere um histograma das idades do Titanic
#
# Escolha um dataset da lista do começo da aula para os próximos exercícios
#
# 3 - Escolha um dataset da lista e utilize o pairplot para analisar o comportamento dos parametros
#
# 4 - Explore a documentação do seaborn e gere alguma visualização interessante que valide alguma hipótese do grupo

# %%
sns.pairplot(df_titanic[['Age', 'Sex', 'Pclass', 'Survived']], hue='Sex')

# %% [markdown]
# ### HeatMap

# %% [markdown]
# O __HeatMap__ (Mapa de Calor) é um gráfico bem interessante quando queremos criar um _Grid_ de variações.<br><br>
# Para usar o HeatMap, vamos definir primeiramente as correlações do DataFrame _Iris_:

# %%
# Out:
#               sepal_length  sepal_width  petal_length  petal_width      size
# sepal_length      1.000000    -0.117570      0.871754     0.817941  0.025553
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126 -0.049211
# petal_length      0.871754    -0.428440      1.000000     0.962865  0.019554
# petal_width       0.817941    -0.366126      0.962865     1.000000  0.024062
# size              0.025553    -0.049211      0.019554     0.024062  1.000000

# %% [markdown]
# A função __corr__ mostra como as variáveis do DataFrame estão relacionadas, ou seja o quanto cada variável influência na variação das outras:

# %%
# Cria o HeatMap


# Mostra o Gráfico
plt.show()

# %% [markdown]
# ##

# %% [markdown]
# ### CountPlot e BarPlot

# %%
car = sns.load_dataset("car_crashes")
cars = car.pivot("speeding", )

# %%
car_crashes = car.pivot("speeding", "alcohol", "total")

# %%
car_crashes
# Out:
# alcohol   1.593   1.808   2.784   2.870   3.136   3.328   3.360   3.429   \
# speeding
# 1.792        NaN     NaN     NaN     NaN    11.2     NaN     NaN     NaN
# 1.886        NaN     NaN     NaN     8.2     NaN     NaN     NaN     NaN
# 1.937        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2.006        5.9     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2.208        NaN     NaN     9.6     NaN     NaN     NaN     NaN     NaN
# 2.413        NaN     NaN     NaN     NaN     NaN     NaN     NaN    12.7
# 2.640        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2.669        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2.964        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3.384        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3.496        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3.625        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3.759        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3.774        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3.936        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3.948        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4.032        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4.060        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4.066        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4.080        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4.095        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4.200        NaN     NaN     NaN     NaN     NaN     NaN    12.0     NaN
# 4.224        NaN     NaN     NaN     NaN     NaN    12.8     NaN     NaN
# 4.250        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4.452        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4.608        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4.806        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4.859        NaN    11.3     NaN     NaN     NaN     NaN     NaN     NaN
# 4.968        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 5.032        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 5.439        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 5.497        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 5.508        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 5.738        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 6.014        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 6.156        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 6.368        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 6.510        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 6.552        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 6.923        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 7.175        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 7.308        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 7.332        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 7.421        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 7.760        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 8.092        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 8.346        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 9.082        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 9.100        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 9.450        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# alcohol   3.480   3.498   ...  5.771   5.824   6.402   6.664   6.765   7.175   \
# speeding                  ...
# 1.792        NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 1.886        NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 1.937        NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 2.006        NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 2.208        NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 2.413        NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 2.640        NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 2.669        NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 2.964        NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 3.384        NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 3.496        NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 3.625        NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 3.759        NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 3.774        NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 3.936        NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 3.948        NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 4.032        NaN     NaN  ...     NaN    22.4     NaN     NaN     NaN     NaN
# 4.060       11.6     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 4.066        NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 4.080        NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 4.095        NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 4.200        NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 4.224        NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 4.250        NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 4.452        NaN    10.6  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 4.608        NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 4.806        NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 4.859        NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 4.968        NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 5.032        NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 5.439        NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 5.497        NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 5.508        NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 5.738        NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 6.014        NaN     NaN  ...     NaN     NaN    19.4     NaN     NaN     NaN
# 6.156        NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 6.368        NaN     NaN  ...    19.9     NaN     NaN     NaN     NaN     NaN
# 6.510        NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 6.552        NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 6.923        NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 7.175        NaN     NaN  ...     NaN     NaN     NaN     NaN    20.5     NaN
# 7.308        NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 7.332        NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 7.421        NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 7.760        NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 8.092        NaN     NaN  ...     NaN     NaN     NaN    23.8     NaN     NaN
# 8.346        NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 9.082        NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 9.100        NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 9.450        NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN    17.5
#
# alcohol   7.372   9.416   9.799   10.038
# speeding
# 1.792        NaN     NaN     NaN     NaN
# 1.886        NaN     NaN     NaN     NaN
# 1.937        NaN     NaN     NaN     NaN
# 2.006        NaN     NaN     NaN     NaN
# 2.208        NaN     NaN     NaN     NaN
# 2.413        NaN     NaN     NaN     NaN
# 2.640        NaN     NaN     NaN     NaN
# 2.669        NaN     NaN     NaN     NaN
# 2.964        NaN     NaN     NaN     NaN
# 3.384        NaN     NaN     NaN     NaN
# 3.496        NaN     NaN     NaN     NaN
# 3.625        NaN     NaN     NaN     NaN
# 3.759        NaN     NaN     NaN     NaN
# 3.774        NaN     NaN     NaN     NaN
# 3.936        NaN     NaN     NaN     NaN
# 3.948        NaN     NaN     NaN     NaN
# 4.032        NaN     NaN     NaN     NaN
# 4.060        NaN     NaN     NaN     NaN
# 4.066        NaN     NaN     NaN     NaN
# 4.080        NaN     NaN     NaN     NaN
# 4.095        NaN     NaN     NaN     NaN
# 4.200        NaN     NaN     NaN     NaN
# 4.224        NaN     NaN     NaN     NaN
# 4.250        NaN     NaN     NaN     NaN
# 4.452        NaN     NaN     NaN     NaN
# 4.608        NaN     NaN     NaN     NaN
# 4.806        NaN     NaN     NaN     NaN
# 4.859        NaN     NaN     NaN     NaN
# 4.968        NaN     NaN     NaN     NaN
# 5.032        NaN     NaN     NaN     NaN
# 5.439        NaN     NaN     NaN     NaN
# 5.497        NaN     NaN     NaN    23.9
# 5.508        NaN     NaN     NaN     NaN
# 5.738        NaN     NaN     NaN     NaN
# 6.014        NaN     NaN     NaN     NaN
# 6.156        NaN     NaN     NaN     NaN
# 6.368        NaN     NaN     NaN     NaN
# 6.510        NaN     NaN     NaN     NaN
# 6.552        NaN     NaN     NaN     NaN
# 6.923        NaN     NaN     NaN     NaN
# 7.175        NaN     NaN     NaN     NaN
# 7.308        NaN     NaN     NaN     NaN
# 7.332        NaN     NaN     NaN     NaN
# 7.421        NaN     NaN     NaN     NaN
# 7.760       19.4     NaN     NaN     NaN
# 8.092        NaN     NaN     NaN     NaN
# 8.346        NaN    21.4     NaN     NaN
# 9.082        NaN     NaN    23.9     NaN
# 9.100        NaN     NaN     NaN     NaN
# 9.450        NaN     NaN     NaN     NaN
#
# [50 rows x 50 columns]

# %%
f, ax = plt.subplots(figsize=(9, 6))
sns.heatmap(car_crashes, annot=True, fmt="d", linewidths=.5, ax=ax)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/alexsander-vieira/Documentos/Python/Aula 4 - Pandas e Seaborn (Durante).ipynb Cell 11' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/home/alexsander-vieira/Documentos/Python/Aula%204%20-%20Pandas%20e%20Seaborn%20%28Durante%29.ipynb#ch0000010?line=0'>1</a> f, ax = plt.subplots(figsize=(9, 6))
# ----> <a href='vscode-notebook-cell:/home/alexsander-vieira/Documentos/Python/Aula%204%20-%20Pandas%20e%20Seaborn%20%28Durante%29.ipynb#ch0000010?line=1'>2</a> sns.heatmap(car_crashes, annot=True, fmt="d", linewidths=.5, ax=ax)
#
# File ~/.local/lib/python3.8/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~/.local/lib/python3.8/site-packages/seaborn/matrix.py:553, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     551 if square:
#     552     ax.set_aspect("equal")
# --> 553 plotter.plot(ax, cbar_ax, kwargs)
#     554 return ax
#
# File ~/.local/lib/python3.8/site-packages/seaborn/matrix.py:348, in _HeatMapper.plot(self, ax, cax, kws)
#     346 # Annotate the cells with the formatted values
#     347 if self.annot:
# --> 348     self._annotate_heatmap(ax, mesh)
#
# File ~/.local/lib/python3.8/site-packages/seaborn/matrix.py:256, in _HeatMapper._annotate_heatmap(self, ax, mesh)
#     254 lum = relative_luminance(color)
#     255 text_color = ".15" if lum > .408 else "w"
# --> 256 annotation = ("{:" + self.fmt + "}").format(val)
#     257 text_kwargs = dict(color=text_color, ha="center", va="center")
#     258 text_kwargs.update(self.annot_kws)
#
# ValueError: Unknown format code 'd' for object of type 'float'

# %% [markdown]
# ##

# %% [markdown]
# ## Desafio

# %% [markdown]
# __1)__ Façam a análise exploratória com o que aprendemos até então (NumPy, Pandas, Matplotlib e Seaborn) num dataset do Kaggle.
# Levante visualizações que possam ser interessantes e tentem interpretar os dados!

# %% [markdown]
# ##

# %% [markdown]
# ## Links, Artigos e Referências:

# %% [markdown]
# - [Documentação do Matplotlib](https://matplotlib.org/), documentação onde vocês podem encontrar mais informações sobre os gráficos do Matplotlib;
# - [Documentação do Seaborn](https://seaborn.pydata.org/), documentação onde vocês podem encontrar mais informações sobre os gráficos do Seaborn;
# - [Documentação do Plotly](https://plotly.com/python/), documentação onde vocês podem encontrar mais informações sobre os gráficos do Plotly;
# - [Beautiful Plots with Python and Seaborn](https://betterprogramming.pub/beautiful-plots-with-python-and-seaborn-9d05c9ead6ed), artigo publicado no blog Better Programming
# - [MAtplotlib vs Seaborn vs Plotly](https://towardsdatascience.com/matplotlib-vs-seaborn-vs-plotly-f2b79f5bddb), artigo publicado pela Towards Data Science comparando as 3 bibliotecas;
# - ["Como criar gráficos interativos utilizando Plotly e Python"](https://paulovasconcellos.com.br/como-criar-gr%C3%A1ficos-interativos-utilizando-plotly-e-python-3eb6eda57a2b?source=---------62----------------------------), artigo escrito por Paulo Vasconcellos para o Data Hackers.
#
# https://www.kaggle.com/datasets/unsdsn/world-happiness
