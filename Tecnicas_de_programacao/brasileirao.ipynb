# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../Python/Brasileirao_Matches.csv')

# %%
df
# Out:
#                  datetime         home_team home_team_state      away_team  \
# 0     2012-05-19 18:30:00      Palmeiras-SP              SP  Portuguesa-SP
# 1     2012-05-19 18:30:00          Sport-PE              PE    Flamengo-RJ
# 2     2012-05-19 21:00:00    Figueirense-SC              SC     Nautico-PE
# 3     2012-05-20 16:00:00    Ponte Preta-SP              SP    Atletico-MG
# 4     2012-05-20 16:00:00    Corinthians-SP              SP  Fluminense-RJ
# ...                   ...               ...             ...            ...
# 4175                  NaN  Internacional-RS              RS   Palmeiras-SP
# 4176                  NaN         Santos-SP              SP   Fortaleza-CE
# 4177                  NaN    Corinthians-SP              SP    Atletico-MG
# 4178                  NaN       Flamengo-RJ              RJ        Avai-SC
# 4179                  NaN        America-MG              MG    Atletico-GO
#
#      away_team_state  home_goal  away_goal  season  round
# ...

# %%
df.shape
# Out:
# (4180, 9)

# %%
df.head()
# Out:
#               datetime       home_team home_team_state      away_team  \
# 0  2012-05-19 18:30:00    Palmeiras-SP              SP  Portuguesa-SP
# 1  2012-05-19 18:30:00        Sport-PE              PE    Flamengo-RJ
# 2  2012-05-19 21:00:00  Figueirense-SC              SC     Nautico-PE
# 3  2012-05-20 16:00:00  Ponte Preta-SP              SP    Atletico-MG
# 4  2012-05-20 16:00:00  Corinthians-SP              SP  Fluminense-RJ
#
#   away_team_state  home_goal  away_goal  season  round
# 0              SP        1.0        1.0    2012      1
# 1              RJ        1.0        1.0    2012      1
# 2              PE        2.0        1.0    2012      1
# 3              MG        0.0        1.0    2012      1
# 4              RJ        0.0        1.0    2012      1

# %%
df.tail()
# Out:
#      datetime         home_team home_team_state     away_team away_team_state  \
# 4175      NaN  Internacional-RS              RS  Palmeiras-SP              SP
# 4176      NaN         Santos-SP              SP  Fortaleza-CE              CE
# 4177      NaN    Corinthians-SP              SP   Atletico-MG              MG
# 4178      NaN       Flamengo-RJ              RJ       Avai-SC              SC
# 4179      NaN        America-MG              MG   Atletico-GO              GO
#
#       home_goal  away_goal  season  round
# 4175        NaN        NaN    2022     38
# 4176        NaN        NaN    2022     38
# 4177        NaN        NaN    2022     38
# 4178        NaN        NaN    2022     38
# 4179        NaN        NaN    2022     38

# %%
df['season']
# Out:
# 0       2012
# 1       2012
# 2       2012
# 3       2012
# 4       2012
#         ...
# 4175    2022
# 4176    2022
# 4177    2022
# 4178    2022
# 4179    2022
# Name: season, Length: 4180, dtype: int64

# %%
df.describe()
# Out:
#          home_goal    away_goal       season        round
# count  3919.000000  3919.000000  4180.000000  4180.000000
# mean      1.411585     0.945649  2017.000000    19.500000
# std       1.156370     0.971443     3.162656    10.967168
# min       0.000000     0.000000  2012.000000     1.000000
# 25%       1.000000     0.000000  2014.000000    10.000000
# 50%       1.000000     1.000000  2017.000000    19.500000
# 75%       2.000000     1.000000  2020.000000    29.000000
# max       6.000000     6.000000  2022.000000    38.000000

# %%
df[df['away_team'] =='Avai-SC']['away_goal'].mean()
# Out:
# 0.6031746031746031

# %%
df[df['away_team'] =='Avai-SC']['home_goal'].mean()
# Out:
# 1.7301587301587302

# %%
df[df['away_team'] =='Figueirense-SC']['away_goal'].mean()
# Out:
# 0.7368421052631579

# %%
df[df['away_team'] =='Figueirense-SC']['home_goal'].mean()
# Out:
# 1.8026315789473684

# %%
df[df['home_team'] == 'Avai-SC']['season']
# Out:
# 1149    2015
# 1167    2015
# 1186    2015
# 1209    2015
# 1220    2015
#         ...
# 4088    2022
# 4092    2022
# 4112    2022
# 4141    2022
# 4165    2022
# Name: season, Length: 76, dtype: int64

# %%
pd.pivot_table(df, values=(['home_goal', 'away_goal']), index='season', columns=(['home_team']), aggfunc=np.mean)
# Out:
#            away_goal                                                          \
# home_team America-MG Atletico-GO Atletico-MG Atletico-PR   Avai-SC  Bahia-BA
# season
# 2012             NaN    1.578947    0.789474         NaN       NaN  0.842105
# 2013             NaN         NaN    0.789474    0.894737       NaN  0.894737
# 2014             NaN         NaN    0.631579    0.736842       NaN  0.894737
# 2015             NaN         NaN    1.052632    1.052632  1.368421       NaN
# 2016        1.052632         NaN    1.052632    0.315789       NaN       NaN
# 2017             NaN    1.210526    1.421053    1.052632  1.052632  1.105263
# 2018        0.894737         NaN    0.789474    0.736842       NaN  0.684211
# 2019             NaN         NaN    1.210526    0.578947  1.263158  0.947368
# 2020             NaN    1.105263    0.684211    0.684211       NaN  1.368421
# 2021        0.578947    0.736842    0.684211    1.105263       NaN  1.157895
# ...

# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt
